# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
data=pd.read_csv("/content/dataset_phishing.csv")

# %%
print(data.head())
# Out:
#                                                  url  length_url  \
# 0              http://www.crestonwood.com/router.php          37
# 1  http://shadetreetechnology.com/V4/validation/a...          77
# 2  https://support-appleld.com.secureupdate.duila...         126
# 3                                 http://rgipt.ac.in          18
# 4  http://www.iracing.com/tracks/gateway-motorspo...          55
#
#    length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  ...  \
# 0               19   0        3           0      0      0       0      0  ...
# 1               23   1        1           0      0      0       0      0  ...
# 2               50   1        4           1      0      1       2      0  ...
# 3               11   0        2           0      0      0       0      0  ...
# 4               15   0        2           2      0      0       0      0  ...
#
#    domain_in_title  domain_with_copyright  whois_registered_domain  \
# ...

# %%
print(data.describe())
# Out:
#          length_url  length_hostname            ip       nb_dots  \
# count  11430.000000     11430.000000  11430.000000  11430.000000
# mean      61.126684        21.090289      0.150569      2.480752
# std       55.297318        10.777171      0.357644      1.369686
# min       12.000000         4.000000      0.000000      1.000000
# 25%       33.000000        15.000000      0.000000      2.000000
# 50%       47.000000        19.000000      0.000000      2.000000
# 75%       71.000000        24.000000      0.000000      3.000000
# max     1641.000000       214.000000      1.000000     24.000000
#
#          nb_hyphens         nb_at         nb_qm        nb_and    nb_or  \
# count  11430.000000  11430.000000  11430.000000  11430.000000  11430.0
# mean       0.997550      0.022222      0.141207      0.162292      0.0
# std        2.087087      0.155500      0.364456      0.821337      0.0
# min        0.000000      0.000000      0.000000      0.000000      0.0
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11430 entries, 0 to 11429
# Data columns (total 89 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   url                         11430 non-null  object
#  1   length_url                  11430 non-null  int64
#  2   length_hostname             11430 non-null  int64
#  3   ip                          11430 non-null  int64
#  4   nb_dots                     11430 non-null  int64
#  5   nb_hyphens                  11430 non-null  int64
#  6   nb_at                       11430 non-null  int64
#  7   nb_qm                       11430 non-null  int64
#  8   nb_and                      11430 non-null  int64
#  9   nb_or                       11430 non-null  int64
#  10  nb_eq                       11430 non-null  int64
#  11  nb_underscore               11430 non-null  int64
#  12  nb_tilde                    11430 non-null  int64
# ...

# %%
print(data)
# Out:
#                                                      url  length_url  \
# 0                  http://www.crestonwood.com/router.php          37
# 1      http://shadetreetechnology.com/V4/validation/a...          77
# 2      https://support-appleld.com.secureupdate.duila...         126
# 3                                     http://rgipt.ac.in          18
# 4      http://www.iracing.com/tracks/gateway-motorspo...          55
# ...                                                  ...         ...
# 11425      http://www.fontspace.com/category/blackletter          45
# 11426  http://www.budgetbots.com/server.php/Server%20...          84
# 11427  https://www.facebook.com/Interactive-Televisio...         105
# 11428             http://www.mypublicdomainpictures.com/          38
# 11429  http://174.139.46.123/ap/signin?openid.pape.ma...         477
#
#        length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  \
# ...

# %%
target = 'length_hostname'

# %%
features = data.drop(columns=[target]).columns

# %%
X = data[features]

# %%
y = data[target]

# %%
data['length_hostname'].values.shape
# Out:
# (11430,)

# %%
data['nb_qm']
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 11425    0
# 11426    1
# 11427    1
# 11428    0
# 11429    1
# Name: nb_qm, Length: 11430, dtype: int64

# %%
m=np.linspace(1,5,10)

# %%
m.reshape(-1,1).shape
# Out:
# (10, 1)

# %%
data.nb_qm.values
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
X_train, X_test, y_train, y_test=train_test_split(data.length_hostname.values.reshape(-1,1), data.nb_qm.values, random_state=11)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_train.shape
# Out:
# (8572, 1)

# %%
X_test.shape
# Out:
# (2858, 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11430 entries, 0 to 11429
# Data columns (total 89 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   url                         11430 non-null  object
#  1   length_url                  11430 non-null  int64
#  2   length_hostname             11430 non-null  int64
#  3   ip                          11430 non-null  int64
#  4   nb_dots                     11430 non-null  int64
#  5   nb_hyphens                  11430 non-null  int64
#  6   nb_at                       11430 non-null  int64
#  7   nb_qm                       11430 non-null  int64
#  8   nb_and                      11430 non-null  int64
#  9   nb_or                       11430 non-null  int64
#  10  nb_eq                       11430 non-null  int64
#  11  nb_underscore               11430 non-null  int64
#  12  nb_tilde                    11430 non-null  int64
# ...

# %%
y_test.shape
# Out:
# (2858,)

# %%
X_train[0]
# Out:
# array([25])

# %%
y_train[0]
# Out:
# 0

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_regresssion=LinearRegression()

# %%
linear_regresssion
# Out:
# LinearRegression()

# %%
linear_regresssion.fit(X=X_train, y=y_train)
# Out:
# LinearRegression()

# %%
linear_regresssion.coef_
# Out:
# array([0.00586692])

# %%
linear_regresssion.intercept_
# Out:
# 0.01845088023279759

# %%
predicted = linear_regresssion.predict(X_test)

# %%
predicted
# Out:
# array([0.13578937, 0.14752322, 0.12992244, ..., 0.11232167, 0.08885397,
#        0.14752322])

# %%
expected =y_test

# %%
expected
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
predicted
# Out:
# array([0.13578937, 0.14752322, 0.12992244, ..., 0.11232167, 0.08885397,
#        0.14752322])

# %%
for p, e in zip(predicted[::], expected[::]):
  print(f'predicted: {p:.2f}, expected: {e:.2f}')
# Out:
# predicted: 0.14, expected: 0.00
# predicted: 0.15, expected: 0.00
# predicted: 0.13, expected: 0.00
# predicted: 0.34, expected: 1.00
# predicted: 0.12, expected: 0.00
# predicted: 0.10, expected: 0.00
# predicted: 0.11, expected: 1.00
# predicted: 0.09, expected: 0.00
# predicted: 0.10, expected: 0.00
# predicted: 0.12, expected: 0.00
# predicted: 0.16, expected: 0.00
# predicted: 0.13, expected: 0.00
# predicted: 0.17, expected: 0.00
# predicted: 0.13, expected: 0.00
# predicted: 0.12, expected: 0.00
# predicted: 0.11, expected: 0.00
# predicted: 0.14, expected: 0.00
# predicted: 0.11, expected: 0.00
# predicted: 0.19, expected: 0.00
# predicted: 0.12, expected: 0.00
# predicted: 0.11, expected: 0.00
# predicted: 0.26, expected: 1.00
# predicted: 0.11, expected: 0.00
# predicted: 0.14, expected: 0.00
# predicted: 0.12, expected: 0.00
# predicted: 0.15, expected: 0.00
# predicted: 0.17, expected: 0.00
# predicted: 0.10, expected: 1.00
# predicted: 0.10, expected: 1.00
# ...

# %%
predict=(lambda date: linear_regresssion.coef_ * date + linear_regresssion.intercept_)

# %%
predict(2080)
# Out:
# array([12.22165371])

# %%
predict(1000)
# Out:
# array([5.88537532])

# %%
max(data.length_hostname.values)
# Out:
# 214

# %%
import seaborn as sns

# %%
axes=sns.scatterplot(data=data, x='length_hostname', y='nb_qm', hue='nb_qm', palette='winter', legend=False)
axes.set_ylim(10,70)
import numpy as np
x=np.array([min(data.length_hostname.values), max(data.length_hostname.values)])
y=predict(x)
import matplotlib.pyplot as plt
line=plt.plot(x,y)
